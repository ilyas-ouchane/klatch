# %% [markdown]
# # Imports

# %%
import pandas as pd
from random import randint

import random as rd
from sklearn.datasets import make_blobs

import numpy as np
import matplotlib.pyplot as plt

import sklearn
from sklearn import datasets
from sklearn import svm 
from sklearn import metrics

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
pd.set_option('display.max_columns', 500)
# pd.set_option('display.width', 5000
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
import sklearn
from sklearn import svm
from sklearn import metrics
import pandas as pd
import numpy as np
from sklearn import linear_model



from sklearn import svm
from sklearn import metrics
import pickle
import pandas as pd
import numpy as np

import pickle
import random
import time

data = pd.read_csv('5clustKlatch.csv', sep=';')
data
def test():
    a=[]
    for i in range(23):
        a.append(randint(1,5))
        random.shuffle(a)
    a.append(randint(18,27))
    a.append(randint(0,1))
    return a

# %% [markdown]
# # Importing Data-Set

# %%
# data
# data.loc[data['clusters']=='clusters-1', 'clusters'] = 1
# data.loc[data['clusters']=='clusters-2', 'clusters'] = 2
# data.loc[data['clusters']=='clusters-3', 'clusters'] = 3
# data.loc[data['clusters']=='clusters-4', 'clusters'] = 4
# data.loc[data['clusters']=='clusters-5', 'clusters'] = 5
# data.loc[data['clusters']=='clusters-6', 'clusters'] = 6
# data.loc[data['clusters']=='clusters-7', 'clusters'] = 7
# data.rename(columns={'$KM-K moyenne':'clusters'},inplace=True)
# print(len(data.columns))
from datetime import datetime


list = [885,
        5,
       2,
       3,
       4,
       4,
       4,
       2,
       2,
       1,
       1,
       2,
        3,
        3,
        4,
        4,
        4,
        5,
        5,
        2,
        3,
        4,
        1,
        22,
        1,             
       ]
# print(len(list))

# generate random integer values
from random import seed
from random import randint
# seed random number generator

# generate some integers



# randint(0,5)

data
# Out:
#      Music  Hiphop, Rap  Raggae  Swing, Jazz  Movies  Comedy  Romantic  \
# 0      5.0          1.0     1.0          1.0     5.0     5.0       4.0
# 1      4.0          1.0     3.0          1.0     5.0     4.0       3.0
# 2      5.0          1.0     4.0          3.0     5.0     4.0       2.0
# 3      5.0          5.0     3.0          2.0     5.0     5.0       2.0
# 4      5.0          4.0     3.0          4.0     5.0     5.0       2.0
# ..     ...          ...     ...          ...     ...     ...       ...
# 868    5.0          5.0     4.0          2.0     5.0     5.0       3.0
# 869    5.0          4.0     1.0          5.0     5.0     4.0       5.0
# 870    4.0          3.0     3.0          2.0     4.0     3.0       5.0
# 871    5.0          2.0     2.0          3.0     5.0     5.0       3.0
# 872    5.0          3.0     1.0          1.0     5.0     5.0       2.0
#
#      Sci-fi  War  Fantasy/Fairy tales  Documentary  Western  History  \
# ...

# %% [markdown]
# # Model

# %%
data = data[['Music', 'Hiphop, Rap', 'Raggae', 'Swing, Jazz', 'Movies',
       'Comedy', 'Romantic', 'Sci-fi', 'War', 'Fantasy/Fairy tales',
       'Documentary', 'Western', 'History', 'Psychology', 'Politics',
       'Reading', 'Languages', 'Musical instruments', 'Writing', 'Sport',
       'Celebrities', 'Science and technology', 'Theatre', 'Age', 'Gender',
       'clusters']]
predict = 'clusters'

X = np.array(data.drop([predict], 1))
Y = np.array(data[predict])

X=X.astype('int')
Y=Y.astype('int')


x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X, Y, test_size=0.1)


clf = svm.SVC(kernel="linear", probability=True) #On peut donner en paramètre kernel and soft margin of the hyperplan
clf.fit(x_train, y_train)


# clf.fit(x_train, y_train)

y_pred = clf.predict(x_test) # Predict values for our test data

acc = metrics.accuracy_score(y_test, y_pred) # Test them against our correct values

scores = cross_val_score(clf, X, Y, cv=30)
print("Accuracy:%0.2f(+/- %0.2f at best)" % (scores.mean(), scores.std() * 2))

# for x in range(len(y_pred)):
#     print('La valeur prédite',y_pred[x],'la vraie valeur', y_test[x])

# scores
# print(scores)
# Out:
# Accuracy:0.81(+/- 0.12 at best)

# %%
# from sklearn import datasets, svm

# clf.fit(X[:-100], Y[:-100]).score(X[-100:], Y[-100:])

# X_folds = np.array_split(X, 100)
# y_folds = np.array_split(Y, 100)

# scores = list()
# for k in range(20):
#     # We use 'list' to copy, in order to 'pop' later on
#     X_train = list(X_folds)
#     X_test = X_train.pop(k)
#     X_train = np.concatenate(X_train)
#     y_train = list(y_folds)
#     y_test = y_train.pop(k)
#     y_train = np.concatenate(y_train)
#     scores.append(clf.fit(X_train, y_train).score(X_test, y_test))

# max_score = [scores.pop(scores.index(max(scores)))]

# max_score

# cross_val_score(clf, X,Y , cv=8, n_jobs=-1, scoring='precision_macro')

# len(data.columns)

# %% [markdown]
# # Confusion Matrix

# %%
# linear = linear_model.LinearRegression()

# linear.fit(x_train,y_train)

# acc=linear.score(x_test,y_test)

# acc

from matplotlib import pyplot as plt
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
#     """
#     This function prints and plots the confusion matrix.
#     Normalization can be applied by setting normalize=True.
#     """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %% [markdown]
# # Results

# %%
cnf_matrix = metrics.confusion_matrix(y_test, y_pred, labels=[1,2,3,4,5])

np.set_printoptions(precision=3)

# # Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['cluster1','cluster2','cluster3','cluster4','cluster5'],
                       title='Confusion matrix, without normalization')
print(metrics.classification_report(y_test, y_pred, labels=[1,2,3,4,5]))
# Out:
# Confusion matrix, without normalization
# [[17  0  1  0  0]
#  [ 0 16  0  0  2]
#  [ 7  0  5  1  0]
#  [ 4  0  1 17  0]
#  [ 0  2  0  0 15]]
#               precision    recall  f1-score   support
#
#            1       0.61      0.94      0.74        18
#            2       0.89      0.89      0.89        18
#            3       0.71      0.38      0.50        13
#            4       0.94      0.77      0.85        22
#            5       0.88      0.88      0.88        17
#
#     accuracy                           0.80        88
#    macro avg       0.81      0.77      0.77        88
# weighted avg       0.82      0.80      0.79        88

# %% [markdown]
# # Random model result generator

# %% [markdown]
# ## Function

# %%
## def gen_rand_Model_results(iter):
#     pickle.dump(clf, open('final_model_klatch.sav', 'wb'))
    loaded_model = pickle.load(open('final_model_klatch.sav', 'rb'))
    res={
      "cluster1": 0,
      "cluster2": 0,
      "cluster3": 0,
      "cluster4": 0,
      "cluster5": 0,
    }
    for i in range(iter):
        A = np.array(test())
        B = A.reshape(1,-1)
#         FUNCTION TO PREDICT FROM MODEL
        result = loaded_model.predict(B) 
        if result==2:
            res["cluster1"]=res["cluster1"]+1
        elif result==1:
            res["cluster2"]=res["cluster2"]+1
        elif result==3:
            res["cluster3"]=res["cluster3"]+1
        elif result==4:
            res["cluster4"]=res["cluster4"]+1
        elif result==5:
            res["cluster5"]=res["cluster5"]+1
    print("Number of clusters determined:")
    return(res)
# Out:
#   File "<ipython-input-9-6f75dc284f7f>", line 3
#     loaded_model = pickle.load(open('final_model_klatch.sav', 'rb'))
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ## Results

# %%
for i in range(1,11,1):
    print("Iter",i,":")
    print(gen_rand_Model_results(1000))
# Out:
# Iter 1 :
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-37eefb6dc5ed> in <module>
#       1 for i in range(1,11,1):
#       2     print("Iter",i,":")
# ----> 3     print(gen_rand_Model_results(1000))
#
# NameError: name 'gen_rand_Model_results' is not defined

# %% [markdown]
# # Testing model with UI

# %% [markdown]
# ## Function

# %%
def test_model(list_user):
#     pickle.dump(clf, open(fn, 'wb'))
    loaded_model = pickle.load(open('final_model_klatch.sav', 'rb'))
    A = np.array([list_user])
    B = A.reshape(1,-1)
    result = loaded_model.predict(B)
    print("Cluster :",result)
    print("User input :", A)

# %% [markdown]
# ## Results

# %%
test_model(test())
# Out:
# Cluster : [5]
# User input : [[ 4  4  3  4  5  4  2  1  3  2  3  2  2  1  4  4  2  3  4  5  3  4  1 19
#    0]]
